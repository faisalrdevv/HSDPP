# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('39 parties Translated + Length.csv')
df.head()
# Out:
#    Unnamed: 0  sr                       date        username  \
# 0           0   0  2022-11-28 20:07:39+00:00  hinaparvezbutt
# 1           1   1  2022-11-28 18:52:10+00:00   MuradSaeedPTI
# 2           2   2  2022-11-28 18:23:32+00:00  AliAminKhanPTI
# 3           3   3  2022-11-28 17:35:24+00:00        ArifAlvi
# 4           4   4  2022-11-28 17:16:53+00:00    KhawajaMAsif
#
#              display name  reply count  tweet count  likes language  \
# 0        Hina Parvez Butt          172           62    348       ur
# 1             Murad Saeed          163         2384   6319      zxx
# 2  Ali Amin Khan Gandapur           41          823   2063       en
# 3           Dr. Arif Alvi           98          342   2998       ur
# 4         Khawaja M. Asif          464          655   2168       ur
#
#                                                tweet  \
# 0  نواز شریف نے عمران خان کو ایسا فیض یاب کیا ہے ...
# 1                            https://t.co/0XXmNKLJZp
# ...

# %%
df = df[df['length'] > 50]
df.head()

# %%
len_tweet = []
for i in range(len(df)):
    x = df.length[i]
    y = df.clean_tweet[i]
    if x > 50:
        print (y)
    else:
        pass
